# %%
import sys
import os
DIRECTORY = os.path.abspath('')
sys.path.append(os.path.join(DIRECTORY, '../src'))
from soc_classifier import SocClassifier

# %% [markdown]
# # Classify SOC Code Directly
#
# This will be worst performing because of the number of classes. One for each individual occupation for a total of 956 occupations. This will not be usable in the current state because of low accuracy.

# %%
soc_code_model = SocClassifier('soc_code')
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# /Users/chartnett/.local/share/virtualenvs/SOC_classifier-CmZmI2qY/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 11.4min finished

# %%
soc_code_model.accuracy()
# Out:
# 0.28291316526610644

# %%
soc_code_model.model['random_forest'].best_params_
# Out:
# {'n_estimators': 1200,
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 50}

# %% [markdown]
# # Classify SOC Major Groups
#
# The next grouping will be the 22 major occupation groups.

# %%
soc_major_model = SocClassifier('major_group')
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  7.9min finished

# %%
soc_major_model.accuracy()
# Out:
# 0.5735739101199149

# %%
import pandas as pd
import seaborn as sns
pd.options.display.max_rows = 23
matrix = soc_major_model.confusion_matrix()
matrix.style.background_gradient(cmap=sns.light_palette("#0B6DB6", as_cmap=True))
# Out:
# <style  type="text/css" >
# ...

# %%
soc_major_model.model['random_forest'].best_params_
# Out:
# {'n_estimators': 600,
#  'min_samples_split': 5,
#  'min_samples_leaf': 3,
#  'max_features': 'sqrt',
#  'max_depth': 100}

# %% [markdown]
# # Classify SOC High Level Groups

# %%
soc_high_level_model = SocClassifier('high_level_groups')
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  9.1min finished

# %%
soc_high_level_model.accuracy()
# Out:
# 0.6232208898352573

# %%
matrix = soc_high_level_model.confusion_matrix()
matrix.style.background_gradient(cmap=sns.light_palette("#0B6DB6", as_cmap=True))
# Out:
# <style  type="text/css" >
# #T_973ef5a4_16fa_11eb_bd9f_f2189823c689row0_col0,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row1_col1,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row2_col2,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row3_col3,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row4_col4,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row5_col5,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row6_col6,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row7_col7,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row8_col8,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row9_col9,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row10_col10,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row11_col11{
#             background-color:  #0b6db6;
#             color:  #f1f1f1;
#         }#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row0_col1{
#             background-color:  #cedeea;
#             color:  #000000;
#         }#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row0_col2,#T_973ef5a4_16fa_11eb_bd9f_f2189823c689row10_col8{
#             background-color:  #e7ebf0;
# ...

# %%
soc_high_level_model.model['random_forest'].best_params_
# Out:
# {'n_estimators': 600,
#  'min_samples_split': 5,
#  'min_samples_leaf': 3,
#  'max_features': 'sqrt',
#  'max_depth': 100}
